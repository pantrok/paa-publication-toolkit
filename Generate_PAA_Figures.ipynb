# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys

PROJECT_ROOT = "/content/drive/MyDrive/Publicaciones/Chillanto CIARP/paa-publication-toolkit"

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

os.chdir(PROJECT_ROOT)

print("Current directory:")
print(os.getcwd())
# Out:
# Current directory:
# /content/drive/MyDrive/Publicaciones/Chillanto CIARP/paa-publication-toolkit

# %%
from paa_toolkit.config import ProjectConfig

config = ProjectConfig(PROJECT_ROOT)

config.create_directories()

config.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_994/2444654017.py in <cell line: 0>()
# ----> 1 from paa_publication_toolkit.config import ProjectConfig
#       2
#       3 config = ProjectConfig(PROJECT_ROOT)
#       4
#       5 config.create_directories()
#
# ModuleNotFoundError: No module named 'paa_publication_toolkit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from paa_toolkit.io import DatasetManager

manager = DatasetManager(config.input)

manager.load()

manager.summary()
